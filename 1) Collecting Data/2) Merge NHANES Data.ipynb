# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
import os

root_folder = f"../Dataset"
output_folder = f"../Dataset/Processed"

# %% [markdown]
# ## Colab Setup (Optional)

# %%
from google.colab import drive
drive.mount('/content/drive')
project_path = "/content/drive/MyDrive/ComBio"
root_folder = f"{project_path}/Dataset"
output_folder = f"{project_path}/Dataset/Processed"

# %% [markdown]
# ## Merge Data

# %%
def clean_nhanes_codes(df):
    df_cleaned = df.copy()
    for col in df_cleaned.columns:
        col_data = df_cleaned[col]
        is_categorical = False
        if col.endswith(('LC', 'FC', 'SI', 'IND', 'CODE')):
            is_categorical = True

        elif col_data.nunique() < 10 and pd.api.types.is_numeric_dtype(col_data):
            is_categorical = True

        if pd.api.types.is_numeric_dtype(col_data) and not is_categorical:
            extreme_mask = (col_data.abs() < 1e-10) & (col_data != 0)
            if extreme_mask.any():
                print(f"Kolom {col}: mengganti {extreme_mask.sum()} nilai ekstrim dengan NaN")
                df_cleaned.loc[extreme_mask, col] = np.nan

        if pd.api.types.is_numeric_dtype(col_data):
            # Nilai negatif dalam NHANES:
            # -1: Refused
            # -2: Don't know
            # -7: Refused to answer
            # -9: Don't know/missing
            nhanes_codes = [-1, -2, -7, -9]
            for code in nhanes_codes:
                code_mask = col_data == code
                if code_mask.any():
                    print(f"Kolom {col}: mengganti {code_mask.sum()} nilai kode {code} dengan NaN")
                    df_cleaned.loc[code_mask, col] = np.nan

    return df_cleaned

def process_nhanes_period(folder, suffix, filename_csv):
    print(f"\n{'='*50}")
    print(f"MEMPROSES DATA NHANES DI FOLDER: {folder}")
    print(f"{'='*50}")

    try:
        if not os.path.exists(folder):
            print(f"Error: Folder {folder} tidak ditemukan!")
            return False

        datasets = {}
        files_to_read = {
            "demo": f"DEMO{suffix}.XPT",
            "biopro": f"BIOPRO{suffix}.XPT",
            "hepc": f"HEPC{suffix}.XPT",
            "mcq": f"MCQ{suffix}.XPT",
            "alq": f"ALQ{suffix}.XPT",
            "duq": f"DUQ{suffix}.XPT",
        }

        for name, filename in files_to_read.items():
            file_path = os.path.join(folder, filename)
            if not os.path.exists(file_path):
                print(f"Warning: File {filename} tidak ditemukan di {folder}")
                print(f"Coba mencari file alternatif...")

                possible_files = [f for f in os.listdir(folder) if f.lower().startswith(name.lower())]
                if possible_files:
                    alt_file = possible_files[0]
                    print(f"Menggunakan file alternatif: {alt_file}")
                    file_path = os.path.join(folder, alt_file)
                else:
                    print(f"Tidak ditemukan file alternatif untuk {name}. Melewati dataset ini.")
                    continue

            try:
                print(f"Membaca file {file_path}...")
                datasets[name] = pd.read_sas(file_path)
                print(f"Berhasil membaca {filename} dengan {len(datasets[name])} baris dan {len(datasets[name].columns)} kolom")
            except Exception as e:
                print(f"Error saat membaca {filename}: {str(e)}")
                print("Melewati dataset ini.")
                continue

        if len(datasets) < 2:
            print("Terlalu sedikit dataset yang berhasil dibaca untuk melakukan merge.")
            print("Minimal diperlukan 2 dataset untuk melanjutkan.")
            return False

        print("\nMembersihkan nilai kode khusus di setiap dataset...")
        cleaned_datasets = {}
        for name, data in datasets.items():
            cleaned_datasets[name] = clean_nhanes_codes(data)

        print("\nMelakukan merge dataset...")
        base_dataset_name = "demo" if "demo" in cleaned_datasets else list(cleaned_datasets.keys())[0]
        merged_df = cleaned_datasets[base_dataset_name]
        print(f"Dataset awal ({base_dataset_name}): {merged_df.shape}")

        for name, data in cleaned_datasets.items():
            if name == base_dataset_name:
                continue

            prev_shape = merged_df.shape
            how_join = "inner" if name in ["biopro", "hepc"] else "left"
            merged_df = merged_df.merge(data, on="SEQN", how=how_join)
            print(f"Setelah merge dengan {name}: {merged_df.shape} (kehilangan {prev_shape[0] - merged_df.shape[0]} baris)")

        print(f"\nDataset gabungan final shape: {merged_df.shape}")

        print("Memeriksa nilai khusus setelah merge...")
        df_final = clean_nhanes_codes(merged_df)

        os.makedirs(output_folder, exist_ok=True)

        output_filename = f"{filename_csv}.csv"
        output_path = os.path.join(output_folder, output_filename)
        print(f"Menyimpan hasil ke {output_path}...")
        df_final.to_csv(output_path, index=False)
        print(f"Dataset berhasil disimpan!")

        print("\nInformasi tentang dataset:")
        for dtype, count in df_final.dtypes.value_counts().items():
            print(f"- {count} kolom dengan tipe data {dtype}")

        return True

    except Exception as e:
        print(f"Error saat memproses data di folder {folder}: {str(e)}")
        return False

# %%
print("PEMROSESAN DATA NHANES UNTUK PERIODE 2005-2006 SAMPAI 2017-2018")
print("===============================================================")


os.makedirs(output_folder, exist_ok=True)

periods = [
    (f"{root_folder}/2005_2006", "_D", "2005-2006"),  # Suffix D
    (f"{root_folder}/2007_2008", "_E", "2007-2008"),  # Suffix E
    (f"{root_folder}/2009_2010", "_F", "2009-2010"),  # Suffix F
    (f"{root_folder}/2011_2012", "_G", "2011-2012"),  # Suffix G
    (f"{root_folder}/2013_2014", "_H", "2013-2014"),  # Suffix H
    (f"{root_folder}/2015_2016", "_I", "2015-2016"),  # Suffix I
    (f"{root_folder}/2017_2018", "_J", "2017-2018"),  # Suffix J
]

success_count = 0
total_periods = len(periods)

for folder, suffix, filename in periods:
    print(f"\nMemproses periode {filename} dengan suffix {suffix}...")
    if process_nhanes_period(folder, suffix, filename):
        success_count += 1
        print(f"\nData {filename} berhasil diproses")
    else:
        print(f"\nGagal memproses data {filename}")

print(f"\nPROSES SELESAI. Berhasil memproses {success_count} dari {total_periods} periode.")
# Out:
# PEMROSESAN DATA NHANES UNTUK PERIODE 2005-2006 SAMPAI 2017-2018
# ===============================================================
#
# Memproses periode 2005-2006 dengan suffix _D...
#
# ==================================================
# MEMPROSES DATA NHANES DI FOLDER: ../Dataset/2005_2006
# ==================================================
# Membaca file ../Dataset/2005_2006\DEMO_D.XPT...
# Berhasil membaca DEMO_D.XPT dengan 10348 baris dan 43 kolom
# Membaca file ../Dataset/2005_2006\BIOPRO_D.XPT...
# Berhasil membaca BIOPRO_D.XPT dengan 6980 baris dan 37 kolom
# Membaca file ../Dataset/2005_2006\HEPC_D.XPT...
# Berhasil membaca HEPC_D.XPT dengan 8086 baris dan 4 kolom
# Membaca file ../Dataset/2005_2006\MCQ_D.XPT...
# Berhasil membaca MCQ_D.XPT dengan 9822 baris dan 89 kolom
# Membaca file ../Dataset/2005_2006\ALQ_D.XPT...
# Berhasil membaca ALQ_D.XPT dengan 4773 baris dan 9 kolom
# Membaca file ../Dataset/2005_2006\DUQ_D.XPT...
# Berhasil membaca DUQ_D.XPT dengan 3285 baris dan 37 kolom
#
# Membersihkan nilai kode khusus di setiap dataset...
# Kolom RIDAGEYR: mengganti 526 nilai ekstrim dengan NaN
# Kolom RIDAGEMN: mengganti 40 nilai ekstrim dengan NaN
# Kolom RIDAGEEX: mengganti 16 nilai ekstrim dengan NaN
# Kolom DMDEDUC3: mengganti 244 nilai ekstrim dengan NaN
# Kolom INDFMPIR: mengganti 76 nilai ekstrim dengan NaN
# Kolom WTMEC2YR: mengganti 398 nilai ekstrim dengan NaN
# Kolom MCQ150Q: mengganti 1028 nilai ekstrim dengan NaN
# Kolom MCQ180B: mengganti 1 nilai ekstrim dengan NaN
# Kolom MCQ180L: mengganti 1 nilai ekstrim dengan NaN
# Kolom MCQ245B: mengganti 2061 nilai ekstrim dengan NaN
# Kolom MCQ340: mengganti 48 nilai ekstrim dengan NaN
# Kolom ALQ120Q: mengganti 925 nilai ekstrim dengan NaN
# Kolom ALQ140Q: mengganti 1775 nilai ekstrim dengan NaN
# Kolom DUQ220Q: mengganti 13 nilai ekstrim dengan NaN
# Kolom DUQ270Q: mengganti 1 nilai ekstrim dengan NaN
# Kolom DUQ310Q: mengganti 1 nilai ekstrim dengan NaN
# Kolom DUQ400Q: mengganti 1 nilai ekstrim dengan NaN
#
# Melakukan merge dataset...
# Dataset awal (demo): (10348, 43)
# Setelah merge dengan biopro: (6980, 79) (kehilangan 3368 baris)
# Setelah merge dengan hepc: (6980, 82) (kehilangan 0 baris)
# Setelah merge dengan mcq: (6980, 170) (kehilangan 0 baris)
# Setelah merge dengan alq: (6980, 178) (kehilangan 0 baris)
# Setelah merge dengan duq: (6980, 214) (kehilangan 0 baris)
#
# Dataset gabungan final shape: (6980, 214)
# Memeriksa nilai khusus setelah merge...
# Menyimpan hasil ke ../Dataset/Processed\2005-2006.csv...
# Dataset berhasil disimpan!
#
# Informasi tentang dataset:
# - 214 kolom dengan tipe data float64
#
# ✅ Data 2005-2006 berhasil diproses
#
# Memproses periode 2007-2008 dengan suffix _E...
#
# ==================================================
# MEMPROSES DATA NHANES DI FOLDER: ../Dataset/2007_2008
# ==================================================
# Membaca file ../Dataset/2007_2008\DEMO_E.XPT...
# Berhasil membaca DEMO_E.XPT dengan 10149 baris dan 43 kolom
# Membaca file ../Dataset/2007_2008\BIOPRO_E.XPT...
# Berhasil membaca BIOPRO_E.XPT dengan 6917 baris dan 37 kolom
# Membaca file ../Dataset/2007_2008\HEPC_E.XPT...
# Berhasil membaca HEPC_E.XPT dengan 8132 baris dan 4 kolom
# Membaca file ../Dataset/2007_2008\MCQ_E.XPT...
# Berhasil membaca MCQ_E.XPT dengan 9666 baris dan 92 kolom
# Membaca file ../Dataset/2007_2008\ALQ_E.XPT...
# Berhasil membaca ALQ_E.XPT dengan 5707 baris dan 9 kolom
# Membaca file ../Dataset/2007_2008\DUQ_E.XPT...
# Berhasil membaca DUQ_E.XPT dengan 4625 baris dan 37 kolom
#
# Membersihkan nilai kode khusus di setiap dataset...
# Kolom RIDAGEYR: mengganti 483 nilai ekstrim dengan NaN
# Kolom RIDAGEMN: mengganti 36 nilai ekstrim dengan NaN
# Kolom RIDAGEEX: mengganti 11 nilai ekstrim dengan NaN
# Kolom DMDEDUC3: mengganti 229 nilai ekstrim dengan NaN
# Kolom INDFMPIR: mengganti 59 nilai ekstrim dengan NaN
# Kolom WTMEC2YR: mengganti 387 nilai ekstrim dengan NaN
# Kolom MCQ150Q: mengganti 721 nilai ekstrim dengan NaN
# Kolom MCQ245B: mengganti 2124 nilai ekstrim dengan NaN
# Kolom MCQ340: mengganti 39 nilai ekstrim dengan NaN
# Kolom ALQ120Q: mengganti 1111 nilai ekstrim dengan NaN
# Kolom ALQ140Q: mengganti 2036 nilai ekstrim dengan NaN
# Kolom DUQ220Q: mengganti 16 nilai ekstrim dengan NaN
# Kolom DUQ260: mengganti 1 nilai ekstrim dengan NaN
# Kolom DUQ270Q: mengganti 1 nilai ekstrim dengan NaN
# Kolom DUQ310Q: mengganti 1 nilai ekstrim dengan NaN
#
# Melakukan merge dataset...
# Dataset awal (demo): (10149, 43)
# Setelah merge dengan biopro: (6917, 79) (kehilangan 3232 baris)
# Setelah merge dengan hepc: (6917, 82) (kehilangan 0 baris)
# Setelah merge dengan mcq: (6917, 173) (kehilangan 0 baris)
# Setelah merge dengan alq: (6917, 181) (kehilangan 0 baris)
# Setelah merge dengan duq: (6917, 217) (kehilangan 0 baris)
#
# Dataset gabungan final shape: (6917, 217)
# Memeriksa nilai khusus setelah merge...
# Menyimpan hasil ke ../Dataset/Processed\2007-2008.csv...
# Dataset berhasil disimpan!
#
# Informasi tentang dataset:
# - 217 kolom dengan tipe data float64
#
# ✅ Data 2007-2008 berhasil diproses
#
# Memproses periode 2009-2010 dengan suffix _F...
#
# ==================================================
# MEMPROSES DATA NHANES DI FOLDER: ../Dataset/2009_2010
# ==================================================
# Membaca file ../Dataset/2009_2010\DEMO_F.XPT...
# Berhasil membaca DEMO_F.XPT dengan 10537 baris dan 43 kolom
# Membaca file ../Dataset/2009_2010\BIOPRO_F.XPT...
# Berhasil membaca BIOPRO_F.XPT dengan 7369 baris dan 37 kolom
# Membaca file ../Dataset/2009_2010\HEPC_F.XPT...
# Berhasil membaca HEPC_F.XPT dengan 8591 baris dan 4 kolom
# Membaca file ../Dataset/2009_2010\MCQ_F.XPT...
# Berhasil membaca MCQ_F.XPT dengan 10109 baris dan 81 kolom
# Membaca file ../Dataset/2009_2010\ALQ_F.XPT...
# Berhasil membaca ALQ_F.XPT dengan 6059 baris dan 9 kolom
# Membaca file ../Dataset/2009_2010\DUQ_F.XPT...
# Berhasil membaca DUQ_F.XPT dengan 5302 baris dan 42 kolom
#
# Membersihkan nilai kode khusus di setiap dataset...
# Kolom RIDAGEYR: mengganti 428 nilai ekstrim dengan NaN
# Kolom RIDAGEMN: mengganti 29 nilai ekstrim dengan NaN
# Kolom RIDAGEEX: mengganti 14 nilai ekstrim dengan NaN
# Kolom DMDEDUC3: mengganti 239 nilai ekstrim dengan NaN
# Kolom INDFMPIR: mengganti 93 nilai ekstrim dengan NaN
# Kolom WTMEC2YR: mengganti 284 nilai ekstrim dengan NaN
# Kolom MCQ180M: mengganti 1 nilai ekstrim dengan NaN
# Kolom MCQ180K: mengganti 1 nilai ekstrim dengan NaN
# Kolom MCQ240DD: mengganti 1 nilai ekstrim dengan NaN
# Kolom ALQ120Q: mengganti 986 nilai ekstrim dengan NaN
# Kolom ALQ140Q: mengganti 2159 nilai ekstrim dengan NaN
# Kolom DUQ210: mengganti 1 nilai ekstrim dengan NaN
# Kolom DUQ213: mengganti 2 nilai ekstrim dengan NaN
# Kolom DUQ215Q: mengganti 32 nilai ekstrim dengan NaN
# Kolom DUQ220Q: mengganti 30 nilai ekstrim dengan NaN
# Kolom DUQ260: mengganti 1 nilai ekstrim dengan NaN
# Kolom DUQ270Q: mengganti 1 nilai ekstrim dengan NaN
# Kolom DUQ310Q: mengganti 1 nilai ekstrim dengan NaN
#
# Melakukan merge dataset...
# Dataset awal (demo): (10537, 43)
# Setelah merge dengan biopro: (7369, 79) (kehilangan 3168 baris)
# Setelah merge dengan hepc: (7369, 82) (kehilangan 0 baris)
# Setelah merge dengan mcq: (7369, 162) (kehilangan 0 baris)
# Setelah merge dengan alq: (7369, 170) (kehilangan 0 baris)
# Setelah merge dengan duq: (7369, 211) (kehilangan 0 baris)
#
# Dataset gabungan final shape: (7369, 211)
# Memeriksa nilai khusus setelah merge...
# Menyimpan hasil ke ../Dataset/Processed\2009-2010.csv...
# Dataset berhasil disimpan!
#
# Informasi tentang dataset:
# - 211 kolom dengan tipe data float64
#
# ✅ Data 2009-2010 berhasil diproses
#
# Memproses periode 2011-2012 dengan suffix _G...
#
# ==================================================
# MEMPROSES DATA NHANES DI FOLDER: ../Dataset/2011_2012
# ==================================================
# Membaca file ../Dataset/2011_2012\DEMO_G.XPT...
# Berhasil membaca DEMO_G.XPT dengan 9756 baris dan 48 kolom
# Membaca file ../Dataset/2011_2012\BIOPRO_G.XPT...
# Berhasil membaca BIOPRO_G.XPT dengan 6549 baris dan 38 kolom
# Membaca file ../Dataset/2011_2012\HEPC_G.XPT...
# Berhasil membaca HEPC_G.XPT dengan 7821 baris dan 4 kolom
# Membaca file ../Dataset/2011_2012\MCQ_G.XPT...
# Berhasil membaca MCQ_G.XPT dengan 9364 baris dan 92 kolom
# Membaca file ../Dataset/2011_2012\ALQ_G.XPT...
# Berhasil membaca ALQ_G.XPT dengan 5615 baris dan 10 kolom
# Membaca file ../Dataset/2011_2012\DUQ_G.XPT...
# Berhasil membaca DUQ_G.XPT dengan 4796 baris dan 42 kolom
#
# Membersihkan nilai kode khusus di setiap dataset...
# Kolom RIDAGEYR: mengganti 392 nilai ekstrim dengan NaN
# Kolom RIDAGEMN: mengganti 34 nilai ekstrim dengan NaN
# Kolom RIDEXAGM: mengganti 8 nilai ekstrim dengan NaN
# Kolom DMDEDUC3: mengganti 282 nilai ekstrim dengan NaN
# Kolom WTMEC2YR: mengganti 418 nilai ekstrim dengan NaN
# Kolom INDFMPIR: mengganti 80 nilai ekstrim dengan NaN
# Kolom MCQ180A: mengganti 1 nilai ekstrim dengan NaN
# Kolom MCQ180B: mengganti 1 nilai ekstrim dengan NaN
# Kolom MCQ180F: mengganti 1 nilai ekstrim dengan NaN
# Kolom MCQ180K: mengganti 1 nilai ekstrim dengan NaN
# Kolom ALQ120Q: mengganti 854 nilai ekstrim dengan NaN
# Kolom ALQ141Q: mengganti 1943 nilai ekstrim dengan NaN
# Kolom DUQ215Q: mengganti 27 nilai ekstrim dengan NaN
# Kolom DUQ220Q: mengganti 18 nilai ekstrim dengan NaN
# Kolom DUQ300: mengganti 1 nilai ekstrim dengan NaN
# Kolom DUQ310Q: mengganti 1 nilai ekstrim dengan NaN
# Kolom DUQ390: mengganti 1 nilai ekstrim dengan NaN
# Kolom DUQ400Q: mengganti 1 nilai ekstrim dengan NaN
#
# Melakukan merge dataset...
# Dataset awal (demo): (9756, 48)
# Setelah merge dengan biopro: (6549, 85) (kehilangan 3207 baris)
# Setelah merge dengan hepc: (6549, 88) (kehilangan 0 baris)
# Setelah merge dengan mcq: (6549, 179) (kehilangan 0 baris)
# Setelah merge dengan alq: (6549, 188) (kehilangan 0 baris)
# Setelah merge dengan duq: (6549, 229) (kehilangan 0 baris)
#
# Dataset gabungan final shape: (6549, 229)
# Memeriksa nilai khusus setelah merge...
# Menyimpan hasil ke ../Dataset/Processed\2011-2012.csv...
# Dataset berhasil disimpan!
#
# Informasi tentang dataset:
# - 229 kolom dengan tipe data float64
#
# ✅ Data 2011-2012 berhasil diproses
#
# Memproses periode 2013-2014 dengan suffix _H...
#
# ==================================================
# MEMPROSES DATA NHANES DI FOLDER: ../Dataset/2013_2014
# ==================================================
# Membaca file ../Dataset/2013_2014\DEMO_H.XPT...
# Berhasil membaca DEMO_H.XPT dengan 10175 baris dan 47 kolom
# Membaca file ../Dataset/2013_2014\BIOPRO_H.XPT...
# Berhasil membaca BIOPRO_H.XPT dengan 6979 baris dan 38 kolom
# Membaca file ../Dataset/2013_2014\HEPC_H.XPT...
# Berhasil membaca HEPC_H.XPT dengan 8291 baris dan 3 kolom
# Membaca file ../Dataset/2013_2014\MCQ_H.XPT...
# Berhasil membaca MCQ_H.XPT dengan 9770 baris dan 95 kolom
# Membaca file ../Dataset/2013_2014\ALQ_H.XPT...
# Berhasil membaca ALQ_H.XPT dengan 5924 baris dan 10 kolom
# Membaca file ../Dataset/2013_2014\DUQ_H.XPT...
# Berhasil membaca DUQ_H.XPT dengan 5057 baris dan 42 kolom
#
# Membersihkan nilai kode khusus di setiap dataset...
# Kolom RIDAGEYR: mengganti 405 nilai ekstrim dengan NaN
# Kolom RIDAGEMN: mengganti 28 nilai ekstrim dengan NaN
# Kolom RIDEXAGM: mengganti 4 nilai ekstrim dengan NaN
# Kolom DMDEDUC3: mengganti 277 nilai ekstrim dengan NaN
# Kolom WTMEC2YR: mengganti 362 nilai ekstrim dengan NaN
# Kolom INDFMPIR: mengganti 105 nilai ekstrim dengan NaN
# Kolom MCQ180B: mengganti 2 nilai ekstrim dengan NaN
# Kolom MCQ180C: mengganti 3 nilai ekstrim dengan NaN
# Kolom MCQ180K: mengganti 4 nilai ekstrim dengan NaN
# Kolom MCQ206: mengganti 1 nilai ekstrim dengan NaN
# Kolom ALQ120Q: mengganti 882 nilai ekstrim dengan NaN
# Kolom ALQ141Q: mengganti 2124 nilai ekstrim dengan NaN
# Kolom ALQ160: mengganti 1454 nilai ekstrim dengan NaN
# Kolom DUQ210: mengganti 2 nilai ekstrim dengan NaN
# Kolom DUQ215Q: mengganti 42 nilai ekstrim dengan NaN
# Kolom DUQ220Q: mengganti 34 nilai ekstrim dengan NaN
# Kolom DUQ310Q: mengganti 1 nilai ekstrim dengan NaN
# Kolom DUQ350Q: mengganti 1 nilai ekstrim dengan NaN
# Kolom DUQ400Q: mengganti 2 nilai ekstrim dengan NaN
#
# Melakukan merge dataset...
# Dataset awal (demo): (10175, 47)
# Setelah merge dengan biopro: (6979, 84) (kehilangan 3196 baris)
# Setelah merge dengan hepc: (6979, 86) (kehilangan 0 baris)
# Setelah merge dengan mcq: (6979, 180) (kehilangan 0 baris)
# Setelah merge dengan alq: (6979, 189) (kehilangan 0 baris)
# Setelah merge dengan duq: (6979, 230) (kehilangan 0 baris)
#
# Dataset gabungan final shape: (6979, 230)
# Memeriksa nilai khusus setelah merge...
# Menyimpan hasil ke ../Dataset/Processed\2013-2014.csv...
# Dataset berhasil disimpan!
#
# Informasi tentang dataset:
# - 230 kolom dengan tipe data float64
#
# ✅ Data 2013-2014 berhasil diproses
#
# Memproses periode 2015-2016 dengan suffix _I...
#
# ==================================================
# MEMPROSES DATA NHANES DI FOLDER: ../Dataset/2015_2016
# ==================================================
# Membaca file ../Dataset/2015_2016\DEMO_I.XPT...
# Berhasil membaca DEMO_I.XPT dengan 9971 baris dan 47 kolom
# Membaca file ../Dataset/2015_2016\BIOPRO_I.XPT...
# Berhasil membaca BIOPRO_I.XPT dengan 6744 baris dan 38 kolom
# Membaca file ../Dataset/2015_2016\HEPC_I.XPT...
# Berhasil membaca HEPC_I.XPT dengan 8021 baris dan 3 kolom
# Membaca file ../Dataset/2015_2016\MCQ_I.XPT...
# Berhasil membaca MCQ_I.XPT dengan 9575 baris dan 90 kolom
# Membaca file ../Dataset/2015_2016\ALQ_I.XPT...
# Berhasil membaca ALQ_I.XPT dengan 5735 baris dan 10 kolom
# Membaca file ../Dataset/2015_2016\DUQ_I.XPT...
# Berhasil membaca DUQ_I.XPT dengan 4843 baris dan 42 kolom
#
# Membersihkan nilai kode khusus di setiap dataset...
# Kolom RIDAGEYR: mengganti 396 nilai ekstrim dengan NaN
# Kolom RIDAGEMN: mengganti 31 nilai ekstrim dengan NaN
# Kolom RIDEXAGM: mengganti 10 nilai ekstrim dengan NaN
# Kolom DMDEDUC3: mengganti 239 nilai ekstrim dengan NaN
# Kolom WTMEC2YR: mengganti 427 nilai ekstrim dengan NaN
# Kolom INDFMPIR: mengganti 92 nilai ekstrim dengan NaN
# Kolom LBXSTB: mengganti 27 nilai ekstrim dengan NaN
# Kolom MCQ180B: mengganti 1 nilai ekstrim dengan NaN
# Kolom MCQ180K: mengganti 1 nilai ekstrim dengan NaN
# Kolom ALQ120Q: mengganti 845 nilai ekstrim dengan NaN
# Kolom ALQ141Q: mengganti 2025 nilai ekstrim dengan NaN
# Kolom ALQ160: mengganti 969 nilai ekstrim dengan NaN
# Kolom DUQ215Q: mengganti 35 nilai ekstrim dengan NaN
# Kolom DUQ220Q: mengganti 23 nilai ekstrim dengan NaN
# Kolom DUQ270Q: mengganti 1 nilai ekstrim dengan NaN
# Kolom DUQ400Q: mengganti 1 nilai ekstrim dengan NaN
#
# Melakukan merge dataset...
# Dataset awal (demo): (9971, 47)
# Setelah merge dengan biopro: (6744, 84) (kehilangan 3227 baris)
# Setelah merge dengan hepc: (6744, 86) (kehilangan 0 baris)
# Setelah merge dengan mcq: (6744, 175) (kehilangan 0 baris)
# Setelah merge dengan alq: (6744, 184) (kehilangan 0 baris)
# Setelah merge dengan duq: (6744, 225) (kehilangan 0 baris)
#
# Dataset gabungan final shape: (6744, 225)
# Memeriksa nilai khusus setelah merge...
# Menyimpan hasil ke ../Dataset/Processed\2015-2016.csv...
# Dataset berhasil disimpan!
#
# Informasi tentang dataset:
# - 225 kolom dengan tipe data float64
#
# ✅ Data 2015-2016 berhasil diproses
#
# Memproses periode 2017-2018 dengan suffix _J...
#
# ==================================================
# MEMPROSES DATA NHANES DI FOLDER: ../Dataset/2017_2018
# ==================================================
# Membaca file ../Dataset/2017_2018\DEMO_J.XPT...
# Berhasil membaca DEMO_J.XPT dengan 9254 baris dan 46 kolom
# Membaca file ../Dataset/2017_2018\BIOPRO_J.XPT...
# Berhasil membaca BIOPRO_J.XPT dengan 6401 baris dan 41 kolom
# Membaca file ../Dataset/2017_2018\HEPC_J.XPT...
# Berhasil membaca HEPC_J.XPT dengan 7435 baris dan 4 kolom
# Membaca file ../Dataset/2017_2018\MCQ_J.XPT...
# Berhasil membaca MCQ_J.XPT dengan 8897 baris dan 76 kolom
# Membaca file ../Dataset/2017_2018\ALQ_J.XPT...
# Berhasil membaca ALQ_J.XPT dengan 5533 baris dan 10 kolom
# Membaca file ../Dataset/2017_2018\DUQ_J.XPT...
# Berhasil membaca DUQ_J.XPT dengan 4572 baris dan 41 kolom
#
# Membersihkan nilai kode khusus di setiap dataset...
# Kolom RIDAGEYR: mengganti 357 nilai ekstrim dengan NaN
# Kolom RIDAGEMN: mengganti 36 nilai ekstrim dengan NaN
# Kolom RIDEXAGM: mengganti 10 nilai ekstrim dengan NaN
# Kolom DMDEDUC3: mengganti 184 nilai ekstrim dengan NaN
# Kolom WTMEC2YR: mengganti 550 nilai ekstrim dengan NaN
# Kolom INDFMPIR: mengganti 91 nilai ekstrim dengan NaN
# Kolom ALQ121: mengganti 1049 nilai ekstrim dengan NaN
# Kolom ALQ142: mengganti 2051 nilai ekstrim dengan NaN
# Kolom ALQ270: mengganti 766 nilai ekstrim dengan NaN
# Kolom ALQ280: mengganti 917 nilai ekstrim dengan NaN
# Kolom ALQ290: mengganti 269 nilai ekstrim dengan NaN
# Kolom ALQ170: mengganti 2562 nilai ekstrim dengan NaN
# Kolom DUQ215Q: mengganti 53 nilai ekstrim dengan NaN
# Kolom DUQ220Q: mengganti 46 nilai ekstrim dengan NaN
# Kolom DUQ400Q: mengganti 1 nilai ekstrim dengan NaN
#
# Melakukan merge dataset...
# Dataset awal (demo): (9254, 46)
# Setelah merge dengan biopro: (6401, 86) (kehilangan 2853 baris)
# Setelah merge dengan hepc: (6401, 89) (kehilangan 0 baris)
# Setelah merge dengan mcq: (6401, 164) (kehilangan 0 baris)
# Setelah merge dengan alq: (6401, 173) (kehilangan 0 baris)
# Setelah merge dengan duq: (6401, 213) (kehilangan 0 baris)
#
# Dataset gabungan final shape: (6401, 213)
# Memeriksa nilai khusus setelah merge...
# Menyimpan hasil ke ../Dataset/Processed\2017-2018.csv...
# Dataset berhasil disimpan!
#
# Informasi tentang dataset:
# - 213 kolom dengan tipe data float64
#
# ✅ Data 2017-2018 berhasil diproses
#
# PROSES SELESAI. Berhasil memproses 7 dari 7 periode.
